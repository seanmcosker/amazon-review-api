# %%
# !pip install lxml
# Out:
# Collecting lxml
#   Using cached lxml-4.9.3.tar.gz (3.6 MB)
# Building wheels for collected packages: lxml
#   Building wheel for lxml (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/seanm/opt/anaconda3/envs/SummerEnv/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/yj/znfgbkgj4f1gvy__jfl3rw6c0000gn/T/pip-install-wgad26fm/lxml_9dbbadff01ed406084bde945503b2180/setup.py'"'"'; __file__='"'"'/private/var/folders/yj/znfgbkgj4f1gvy__jfl3rw6c0000gn/T/pip-install-wgad26fm/lxml_9dbbadff01ed406084bde945503b2180/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/yj/znfgbkgj4f1gvy__jfl3rw6c0000gn/T/pip-wheel-vznnuyos
#        cwd: /private/var/folders/yj/znfgbkgj4f1gvy__jfl3rw6c0000gn/T/pip-install-wgad26fm/lxml_9dbbadff01ed406084bde945503b2180/
#   Complete output (125 lines):
#   Building lxml version 4.9.3.
#   Building without Cython.
#   Building against libxml2 2.9.14 and libxslt 1.1.35
#   Building against libxml2/libxslt in one of the following directories:
#     /Users/seanm/opt/anaconda3/envs/SummerEnv/lib
#     /Users/seanm/opt/anaconda3/envs/SummerEnv/lib
#     /Users/seanm/opt/anaconda3/envs/SummerEnv/lib
#     /Users/seanm/opt/anaconda3/envs/SummerEnv/lib
#     /Users/seanm/opt/anaconda3/envs/SummerEnv/lib
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.9-x86_64-3.8
#   creating build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/_elementpath.py -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/sax.py -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/pyclasslookup.py -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/builder.py -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/doctestcompare.py -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/usedoctest.py -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/cssselect.py -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/ElementInclude.py -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   creating build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#   copying src/lxml/includes/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#   creating build/lib.macosx-10.9-x86_64-3.8/lxml/html
#   copying src/lxml/html/soupparser.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#   copying src/lxml/html/defs.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#   copying src/lxml/html/_setmixin.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#   copying src/lxml/html/clean.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#   copying src/lxml/html/_diffcommand.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#   copying src/lxml/html/html5parser.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#   copying src/lxml/html/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#   copying src/lxml/html/formfill.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#   copying src/lxml/html/builder.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#   copying src/lxml/html/ElementSoup.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#   copying src/lxml/html/_html5builder.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#   copying src/lxml/html/usedoctest.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#   copying src/lxml/html/diff.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#   creating build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron
#   copying src/lxml/isoschematron/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron
#   copying src/lxml/etree.h -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/etree_api.h -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/lxml.etree.h -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/lxml.etree_api.h -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/objectify.pyx -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/etree.pyx -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/public-api.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/xmlid.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/cleanup.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/xslt.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/xpath.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/debug.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/serializer.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/classlookup.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/saxparser.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/objectpath.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/relaxng.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/xinclude.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/iterparse.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/parser.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/dtd.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/apihelpers.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/xmlerror.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/readonlytree.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/extensions.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/xmlschema.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/schematron.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/docloader.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/nsclasses.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/parsertarget.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/xsltext.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/proxy.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#   copying src/lxml/includes/xmlerror.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#   copying src/lxml/includes/c14n.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#   copying src/lxml/includes/xmlschema.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#   copying src/lxml/includes/__init__.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#   copying src/lxml/includes/schematron.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#   copying src/lxml/includes/tree.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#   copying src/lxml/includes/uri.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#   copying src/lxml/includes/etreepublic.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#   copying src/lxml/includes/xpath.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#   copying src/lxml/includes/htmlparser.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#   copying src/lxml/includes/xslt.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#   copying src/lxml/includes/config.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#   copying src/lxml/includes/xmlparser.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#   copying src/lxml/includes/xinclude.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#   copying src/lxml/includes/dtdvalid.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#   copying src/lxml/includes/relaxng.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#   copying src/lxml/includes/lxml-version.h -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#   copying src/lxml/includes/etree_defs.h -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#   creating build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources
#   creating build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources/rng
#   copying src/lxml/isoschematron/resources/rng/iso-schematron.rng -> build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources/rng
#   creating build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources/xsl
#   copying src/lxml/isoschematron/resources/xsl/XSD2Schtrn.xsl -> build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources/xsl
#   copying src/lxml/isoschematron/resources/xsl/RNG2Schtrn.xsl -> build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources/xsl
#   creating build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#   copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_abstract_expand.xsl -> build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#   copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_dsdl_include.xsl -> build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#   copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_schematron_skeleton_for_xslt1.xsl -> build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#   copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_svrl_for_xslt1.xsl -> build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#   copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_schematron_message.xsl -> build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#   copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/readme.txt -> build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#   running build_ext
#   building 'lxml.etree' extension
#   creating build/temp.macosx-10.9-x86_64-3.8
#   creating build/temp.macosx-10.9-x86_64-3.8/src
#   creating build/temp.macosx-10.9-x86_64-3.8/src/lxml
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/seanm/opt/anaconda3/envs/SummerEnv/include -arch x86_64 -I/Users/seanm/opt/anaconda3/envs/SummerEnv/include -arch x86_64 -DCYTHON_CLINE_IN_TRACEBACK=0 -I/Users/seanm/opt/anaconda3/envs/SummerEnv/include/libxml2 -I/Users/seanm/opt/anaconda3/envs/SummerEnv/include -Isrc -Isrc/lxml/includes -I/Users/seanm/opt/anaconda3/envs/SummerEnv/include/python3.8 -c src/lxml/etree.c -o build/temp.macosx-10.9-x86_64-3.8/src/lxml/etree.o -w -flat_namespace
#   xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#   Compile failed: command '/usr/bin/gcc' failed with exit code 1
#   creating var
#   creating var/folders
#   creating var/folders/yj
#   creating var/folders/yj/znfgbkgj4f1gvy__jfl3rw6c0000gn
#   creating var/folders/yj/znfgbkgj4f1gvy__jfl3rw6c0000gn/T
#   cc -I/Users/seanm/opt/anaconda3/envs/SummerEnv/include/libxml2 -I/Users/seanm/opt/anaconda3/envs/SummerEnv/include -I/usr/include/libxml2 -c /var/folders/yj/znfgbkgj4f1gvy__jfl3rw6c0000gn/T/xmlXPathInitl5g8byqu.c -o var/folders/yj/znfgbkgj4f1gvy__jfl3rw6c0000gn/T/xmlXPathInitl5g8byqu.o
#   xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#   *********************************************************************************
#   Could not find function xmlCheckVersion in library libxml2. Is libxml2 installed?
#   Perhaps try: xcode-select --install
#   *********************************************************************************
#   error: command '/usr/bin/gcc' failed with exit code 1
#   ----------------------------------------
#   ERROR: Failed building wheel for lxml
#   Running setup.py clean for lxml
# Failed to build lxml
# Installing collected packages: lxml
#     Running setup.py install for lxml ... error
#     ERROR: Command errored out with exit status 1:
#      command: /Users/seanm/opt/anaconda3/envs/SummerEnv/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/yj/znfgbkgj4f1gvy__jfl3rw6c0000gn/T/pip-install-wgad26fm/lxml_9dbbadff01ed406084bde945503b2180/setup.py'"'"'; __file__='"'"'/private/var/folders/yj/znfgbkgj4f1gvy__jfl3rw6c0000gn/T/pip-install-wgad26fm/lxml_9dbbadff01ed406084bde945503b2180/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/yj/znfgbkgj4f1gvy__jfl3rw6c0000gn/T/pip-record-klnw9jc4/install-record.txt --single-version-externally-managed --compile --install-headers /Users/seanm/opt/anaconda3/envs/SummerEnv/include/python3.8/lxml
#          cwd: /private/var/folders/yj/znfgbkgj4f1gvy__jfl3rw6c0000gn/T/pip-install-wgad26fm/lxml_9dbbadff01ed406084bde945503b2180/
#     Complete output (122 lines):
#     Building lxml version 4.9.3.
#     Building without Cython.
#     Building against libxml2 2.9.14 and libxslt 1.1.35
#     Building against libxml2/libxslt in one of the following directories:
#       /Users/seanm/opt/anaconda3/envs/SummerEnv/lib
#       /Users/seanm/opt/anaconda3/envs/SummerEnv/lib
#       /Users/seanm/opt/anaconda3/envs/SummerEnv/lib
#       /Users/seanm/opt/anaconda3/envs/SummerEnv/lib
#       /Users/seanm/opt/anaconda3/envs/SummerEnv/lib
#     running install
#     /Users/seanm/opt/anaconda3/envs/SummerEnv/lib/python3.8/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.9-x86_64-3.8
#     creating build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/_elementpath.py -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/sax.py -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/pyclasslookup.py -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/builder.py -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/doctestcompare.py -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/usedoctest.py -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/cssselect.py -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/ElementInclude.py -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     creating build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#     copying src/lxml/includes/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#     creating build/lib.macosx-10.9-x86_64-3.8/lxml/html
#     copying src/lxml/html/soupparser.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#     copying src/lxml/html/defs.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#     copying src/lxml/html/_setmixin.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#     copying src/lxml/html/clean.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#     copying src/lxml/html/_diffcommand.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#     copying src/lxml/html/html5parser.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#     copying src/lxml/html/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#     copying src/lxml/html/formfill.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#     copying src/lxml/html/builder.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#     copying src/lxml/html/ElementSoup.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#     copying src/lxml/html/_html5builder.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#     copying src/lxml/html/usedoctest.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#     copying src/lxml/html/diff.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/html
#     creating build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron
#     copying src/lxml/isoschematron/__init__.py -> build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron
#     copying src/lxml/etree.h -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/etree_api.h -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/lxml.etree.h -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/lxml.etree_api.h -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/objectify.pyx -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/etree.pyx -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/public-api.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/xmlid.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/cleanup.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/xslt.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/xpath.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/debug.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/serializer.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/classlookup.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/saxparser.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/objectpath.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/relaxng.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/xinclude.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/iterparse.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/parser.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/dtd.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/apihelpers.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/xmlerror.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/readonlytree.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/extensions.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/xmlschema.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/schematron.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/docloader.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/nsclasses.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/parsertarget.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/xsltext.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/proxy.pxi -> build/lib.macosx-10.9-x86_64-3.8/lxml
#     copying src/lxml/includes/xmlerror.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#     copying src/lxml/includes/c14n.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#     copying src/lxml/includes/xmlschema.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#     copying src/lxml/includes/__init__.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#     copying src/lxml/includes/schematron.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#     copying src/lxml/includes/tree.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#     copying src/lxml/includes/uri.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#     copying src/lxml/includes/etreepublic.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#     copying src/lxml/includes/xpath.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#     copying src/lxml/includes/htmlparser.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#     copying src/lxml/includes/xslt.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#     copying src/lxml/includes/config.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#     copying src/lxml/includes/xmlparser.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#     copying src/lxml/includes/xinclude.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#     copying src/lxml/includes/dtdvalid.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#     copying src/lxml/includes/relaxng.pxd -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#     copying src/lxml/includes/lxml-version.h -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#     copying src/lxml/includes/etree_defs.h -> build/lib.macosx-10.9-x86_64-3.8/lxml/includes
#     creating build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources
#     creating build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources/rng
#     copying src/lxml/isoschematron/resources/rng/iso-schematron.rng -> build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources/rng
#     creating build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources/xsl
#     copying src/lxml/isoschematron/resources/xsl/XSD2Schtrn.xsl -> build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources/xsl
#     copying src/lxml/isoschematron/resources/xsl/RNG2Schtrn.xsl -> build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources/xsl
#     creating build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#     copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_abstract_expand.xsl -> build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#     copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_dsdl_include.xsl -> build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#     copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_schematron_skeleton_for_xslt1.xsl -> build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#     copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_svrl_for_xslt1.xsl -> build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#     copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/iso_schematron_message.xsl -> build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#     copying src/lxml/isoschematron/resources/xsl/iso-schematron-xslt1/readme.txt -> build/lib.macosx-10.9-x86_64-3.8/lxml/isoschematron/resources/xsl/iso-schematron-xslt1
#     running build_ext
#     building 'lxml.etree' extension
#     creating build/temp.macosx-10.9-x86_64-3.8
#     creating build/temp.macosx-10.9-x86_64-3.8/src
#     creating build/temp.macosx-10.9-x86_64-3.8/src/lxml
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/seanm/opt/anaconda3/envs/SummerEnv/include -arch x86_64 -I/Users/seanm/opt/anaconda3/envs/SummerEnv/include -arch x86_64 -DCYTHON_CLINE_IN_TRACEBACK=0 -I/Users/seanm/opt/anaconda3/envs/SummerEnv/include/libxml2 -I/Users/seanm/opt/anaconda3/envs/SummerEnv/include -Isrc -Isrc/lxml/includes -I/Users/seanm/opt/anaconda3/envs/SummerEnv/include/python3.8 -c src/lxml/etree.c -o build/temp.macosx-10.9-x86_64-3.8/src/lxml/etree.o -w -flat_namespace
#     xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#     Compile failed: command '/usr/bin/gcc' failed with exit code 1
#     cc -I/Users/seanm/opt/anaconda3/envs/SummerEnv/include/libxml2 -I/Users/seanm/opt/anaconda3/envs/SummerEnv/include -I/usr/include/libxml2 -c /var/folders/yj/znfgbkgj4f1gvy__jfl3rw6c0000gn/T/xmlXPathInitevxy5dwe.c -o var/folders/yj/znfgbkgj4f1gvy__jfl3rw6c0000gn/T/xmlXPathInitevxy5dwe.o
#     xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#     *********************************************************************************
#     Could not find function xmlCheckVersion in library libxml2. Is libxml2 installed?
#     Perhaps try: xcode-select --install
#     *********************************************************************************
#     error: command '/usr/bin/gcc' failed with exit code 1
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /Users/seanm/opt/anaconda3/envs/SummerEnv/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/yj/znfgbkgj4f1gvy__jfl3rw6c0000gn/T/pip-install-wgad26fm/lxml_9dbbadff01ed406084bde945503b2180/setup.py'"'"'; __file__='"'"'/private/var/folders/yj/znfgbkgj4f1gvy__jfl3rw6c0000gn/T/pip-install-wgad26fm/lxml_9dbbadff01ed406084bde945503b2180/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/yj/znfgbkgj4f1gvy__jfl3rw6c0000gn/T/pip-record-klnw9jc4/install-record.txt --single-version-externally-managed --compile --install-headers /Users/seanm/opt/anaconda3/envs/SummerEnv/include/python3.8/lxml Check the logs for full command output.

# %%
from flask import Flask, request, jsonify
import selectorlib
import requests
from dateutil import parser as dateparser
app = Flask(__name__)
extractor = selectorlib.Extractor.from_yaml_file('selectors.yml')

def scrape(url):    
    headers = {
        'authority': 'www.amazon.com',
        'pragma': 'no-cache',
        'cache-control': 'no-cache',
        'dnt': '1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (X11; CrOS x86_64 8172.45.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.64 Safari/537.36',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'sec-fetch-site': 'none',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-dest': 'document',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
    }

    # Download the page using requests
    print("Downloading %s"%url)
    r = requests.get(url, headers=headers)
    # Simple check to check if page was blocked (Usually 503)
    if r.status_code > 500:
        if "To discuss automated access to Amazon data please contact" in r.text:
            print("Page %s was blocked by Amazon. Please try using better proxies\n"%url)
        else:
            print("Page %s must have been blocked by Amazon as the status code was %d"%(url,r.status_code))
        return None
    # Pass the HTML of the page and create 
    data = extractor.extract(r.text,base_url=url)
    reviews = []
    for r in data['reviews']:
        r["product"] = data["product_title"]
        r['url'] = url
        if 'verified_purchase' in r:
            if 'Verified Purchase' in r['verified_purchase']:
                r['verified_purchase'] = True
            else:
                r['verified_purchase'] = False
        r['rating'] = r['rating'].split(' out of')[0]
        date_posted = r['date'].split('on ')[-1]
        if r['images']:
            r['images'] = "\n".join(r['images'])
        r['date'] = dateparser.parse(date_posted).strftime('%d %b %Y')
        reviews.append(r)
    histogram = {}
    for h in data['histogram']:
        histogram[h['key']] = h['value']
    data['histogram'] = histogram
    data['average_rating'] = float(data['average_rating'].split(' out')[0])
    data['reviews'] = reviews
    data['number_of_reviews'] = int(data['number_of_reviews'].split('  customer')[0])
    return data 
    
@app.route('/')
def api():
    url = request.args.get('url',None)
    if url:
        data = scrape(url)
        return jsonify(data)
    return jsonify({'error':'URL to scrape is not provided'}),400
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/seanm/Desktop/amazon-review-api/yankee-candle.ipynb Cell 1 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/seanm/Desktop/amazon-review-api/yankee-candle.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> from flask import Flask, request, jsonify
# ----> <a href='vscode-notebook-cell:/Users/seanm/Desktop/amazon-review-api/yankee-candle.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> import selectorlib
#       <a href='vscode-notebook-cell:/Users/seanm/Desktop/amazon-review-api/yankee-candle.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> import requests
#       <a href='vscode-notebook-cell:/Users/seanm/Desktop/amazon-review-api/yankee-candle.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> from dateutil import parser as dateparser
#
# ModuleNotFoundError: No module named 'selectorlib'
